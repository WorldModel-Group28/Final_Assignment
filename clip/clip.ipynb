# %%
# !pip install torch torchvision
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting torch
#   Downloading torch-2.2.0-cp39-cp39-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting torchvision
#   Downloading torchvision-0.17.0-cp39-cp39-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch) (4.9.0)
# Collecting sympy (from torch)
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch)
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from torch)
#   Using cached fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 1.7 MB/s eta 0:00:0000:0100:01m
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 1.7 MB/s eta 0:00:0000:0100:01m
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.9 MB/s eta 0:00:0000:0100:05
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.9 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.2 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.0 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting triton==2.2.0 (from torch)
#   Downloading triton-2.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torchvision) (1.26.3)
# Requirement already satisfied: requests in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torchvision) (10.2.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-2.1.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests->torchvision) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests->torchvision) (2023.11.17)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading torch-2.2.0-cp39-cp39-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.8 MB/s eta 0:00:0000:0100:07
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:0000:0100:05
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.1 MB/s eta 0:00:0000:0100:02
# Downloading triton-2.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 3.5 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.17.0-cp39-cp39-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 4.0 MB/s eta 0:00:0000:0100:01
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 4.0 MB/s eta 0:00:00
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Downloading MarkupSafe-2.1.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 4.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: mpmath, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision
# Successfully installed MarkupSafe-2.1.5 filelock-3.13.1 fsspec-2023.12.2 jinja2-3.1.3 mpmath-1.3.0 networkx-3.2.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 sympy-1.12 torch-2.2.0 torchvision-0.17.0 triton-2.2.0
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-2ahqy4sg
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-2ahqy4sg
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: regex in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from clip==1.0) (2023.12.25)
# Requirement already satisfied: tqdm in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from clip==1.0) (4.66.1)
# Requirement already satisfied: torch in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from clip==1.0) (2.2.0)
# Requirement already satisfied: torchvision in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from clip==1.0) (0.17.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (4.9.0)
# Requirement already satisfied: sympy in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (1.12)
# Requirement already satisfied: networkx in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (3.1.3)
# Requirement already satisfied: fsspec in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (2023.12.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torch->clip==1.0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->clip==1.0) (12.3.101)
# Requirement already satisfied: numpy in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torchvision->clip==1.0) (1.26.3)
# Requirement already satisfied: requests in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torchvision->clip==1.0) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from torchvision->clip==1.0) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from jinja2->torch->clip==1.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests->torchvision->clip==1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests->torchvision->clip==1.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests->torchvision->clip==1.0) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from requests->torchvision->clip==1.0) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /home/kako/anaconda3/envs/myenv/lib/python3.9/site-packages (from sympy->torch->clip==1.0) (1.3.0)
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 1.5 MB/s eta 0:00:00
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369497 sha256=057bff8cb8007b002899cdcb7ec411e730ab96cbb97963e09358cc8507b843ef
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gwxix5lf/wheels/c8/e4/e1/11374c111387672fc2068dfbe0d4b424cb9cdd1b2e184a71b5
# Successfully built clip
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.1.3

# %%
import os
import csv
import clip
import torch
from PIL import Image

def load_clip_model():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model, preprocess = clip.load("ViT-B/32", device=device)
    return model, preprocess, device

def predict_choice(model, preprocess, device, image_path, text_descriptions):
    image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
    text = clip.tokenize(text_descriptions).to(device)

    with torch.no_grad():
        image_features = model.encode_image(image)
        text_features = model.encode_text(text)

        # 類似度スコアの計算（修正部分）
        logits_per_image = (image_features @ text_features.T).softmax(dim=-1)
        probs = logits_per_image.cpu().numpy()

    return probs[0]


def main():
    model, preprocess, device = load_clip_model()
    base_dir = "clip_dataset"
    images_dir = os.path.join(base_dir, "images")
    csv_file_path = os.path.join(base_dir, "dataset.csv")

    with open(csv_file_path, 'r', newline='', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            image_path = os.path.join(images_dir, row["image_filename"])
            text_description = row["text_description"]
            button_texts = row["button_texts"].split('|')
            text_descriptions = [f"{text_description} {btn_text}" for btn_text in button_texts]

            probs = predict_choice(model, preprocess, device, image_path, text_descriptions)
            best_choice_index = probs.argmax()
            print(f"Image: {row['image_filename']}, Best choice: {button_texts[best_choice_index]}, Probability: {probs[best_choice_index]:.4f}")

if __name__ == "__main__":
    main()
# Out:
# Image: image_0001.png, Best choice: 1, Probability: 0.2991
# Image: image_0002.png, Best choice:  , Probability: 0.1423
# Image: image_0003.png, Best choice: 9, Probability: 0.1183
# Image: image_0004.png, Best choice: 0, Probability: 0.2292
# Image: image_0005.png, Best choice: 2, Probability: 0.1296
# Image: image_0006.png, Best choice: 9, Probability: 0.1404
# Image: image_0007.png, Best choice: 9, Probability: 0.1422
# Image: image_0008.png, Best choice: 8, Probability: 0.1743
# Image: image_0009.png, Best choice: 9, Probability: 0.1554
# Image: image_0010.png, Best choice: 8, Probability: 0.2101
# Image: image_0011.png, Best choice: 1, Probability: 0.1572
# Image: image_0012.png, Best choice: 0, Probability: 0.2242
# Image: image_0013.png, Best choice: 1, Probability: 0.2257
# Image: image_0014.png, Best choice:  , Probability: 0.1493
# Image: image_0015.png, Best choice: 1, Probability: 0.1587
# Image: image_0016.png, Best choice: 5, Probability: 0.1846
# Image: image_0017.png, Best choice: 1, Probability: 0.1724
# Image: image_0018.png, Best choice: 1, Probability: 0.2440
# Image: image_0019.png, Best choice: 0, Probability: 0.2617
# Image: image_0020.png, Best choice:  , Probability: 0.1641
# Image: image_0021.png, Best choice: 3, Probability: 0.2708
# Image: image_0022.png, Best choice: 5, Probability: 0.1390
# Image: image_0023.png, Best choice: 0, Probability: 0.1312
# Image: image_0024.png, Best choice: 0, Probability: 0.1785
# Image: image_0025.png, Best choice: 0, Probability: 0.1670
# Image: image_0026.png, Best choice: 2, Probability: 0.3262
# Image: image_0027.png, Best choice: 0, Probability: 0.1846
# Image: image_0028.png, Best choice: 1, Probability: 0.1899
# Image: image_0029.png, Best choice: 6, Probability: 0.3469
# Image: image_0030.png, Best choice: 5, Probability: 0.1375
# Image: image_0031.png, Best choice: 0, Probability: 0.1394
# Image: image_0032.png, Best choice: 0, Probability: 0.2576
# Image: image_0033.png, Best choice: 6, Probability: 0.2759
# Image: image_0034.png, Best choice:  , Probability: 0.1243
# Image: image_0035.png, Best choice: 6, Probability: 0.2389
# Image: image_0036.png, Best choice: 6, Probability: 0.2634
# Image: image_0037.png, Best choice: 2, Probability: 0.1862
# Image: image_0038.png, Best choice: 6, Probability: 0.2023
# Image: image_0039.png, Best choice: 2, Probability: 0.2271
# Image: image_0040.png, Best choice: 9, Probability: 0.1361
# Image: image_0041.png, Best choice: 6, Probability: 0.1223
# Image: image_0042.png, Best choice: 4, Probability: 0.4333
# Image: image_0043.png, Best choice: 3, Probability: 0.1382
# Image: image_0044.png, Best choice: 4, Probability: 0.2275
# Image: image_0045.png, Best choice: 6, Probability: 0.1525
# Image: image_0046.png, Best choice: 8, Probability: 0.1997
# Image: image_0047.png, Best choice:  , Probability: 0.1353
# Image: image_0048.png, Best choice: 1, Probability: 0.1964
# Image: image_0049.png, Best choice: 6, Probability: 0.1393
# Image: image_0050.png, Best choice: 1, Probability: 0.1483
# Image: image_0051.png, Best choice: 0, Probability: 0.2306
# Image: image_0052.png, Best choice: 1, Probability: 0.2025
# Image: image_0053.png, Best choice: 0, Probability: 0.2363
# Image: image_0054.png, Best choice: 1, Probability: 0.1935
# Image: image_0055.png, Best choice: 6, Probability: 0.1759
# Image: image_0056.png, Best choice: 8, Probability: 0.2671
# Image: image_0057.png, Best choice: 1, Probability: 0.1758
# Image: image_0058.png, Best choice: 0, Probability: 0.1209
# Image: image_0059.png, Best choice: 1, Probability: 0.1912
# Image: image_0060.png, Best choice:  , Probability: 0.1498
# Image: image_0061.png, Best choice: 2, Probability: 0.1777
# Image: image_0062.png, Best choice: 8, Probability: 0.1757
# Image: image_0063.png, Best choice: 5, Probability: 0.1956
# Image: image_0064.png, Best choice: 4, Probability: 0.5176
# Image: image_0065.png, Best choice: 8, Probability: 0.1572
# Image: image_0066.png, Best choice: 1, Probability: 0.2166
# Image: image_0067.png, Best choice: 0, Probability: 0.2317
# Image: image_0068.png, Best choice: 2, Probability: 0.1377
# Image: image_0069.png, Best choice: 1, Probability: 0.2031
# Image: image_0070.png, Best choice: 1, Probability: 0.2024
# Image: image_0071.png, Best choice: 5, Probability: 0.1897
# Image: image_0072.png, Best choice: 1, Probability: 0.1462
# Image: image_0073.png, Best choice: 8, Probability: 0.2404
# Image: image_0074.png, Best choice: 9, Probability: 0.1589
# Image: image_0075.png, Best choice: 1, Probability: 0.1735
# Image: image_0076.png, Best choice: 6, Probability: 0.1719
# Image: image_0077.png, Best choice: 1, Probability: 0.2373
# Image: image_0078.png, Best choice: 6, Probability: 0.1293
# Image: image_0079.png, Best choice: 8, Probability: 0.1796
# Image: image_0080.png, Best choice:  , Probability: 0.1354
# Image: image_0081.png, Best choice: 1, Probability: 0.2256
# Image: image_0082.png, Best choice:  , Probability: 0.1215
# Image: image_0083.png, Best choice: 3, Probability: 0.1423
# Image: image_0084.png, Best choice: 8, Probability: 0.1985
# Image: image_0085.png, Best choice: 1, Probability: 0.1896
# Image: image_0086.png, Best choice: 2, Probability: 0.1525
# Image: image_0087.png, Best choice: 3, Probability: 0.1448
# Image: image_0088.png, Best choice: 2, Probability: 0.1910
# Image: image_0089.png, Best choice:  , Probability: 0.1783
# Image: image_0090.png, Best choice: 1, Probability: 0.1871
# Image: image_0091.png, Best choice: 1, Probability: 0.2191
# Image: image_0092.png, Best choice: 0, Probability: 0.4563
# Image: image_0093.png, Best choice: 3, Probability: 0.1863
# Image: image_0094.png, Best choice: 2, Probability: 0.1558
# Image: image_0095.png, Best choice: 0, Probability: 0.2820
# Image: image_0096.png, Best choice: 6, Probability: 0.1334
# Image: image_0097.png, Best choice: 9, Probability: 0.1744
# Image: image_0098.png, Best choice: 1, Probability: 0.1720
# Image: image_0099.png, Best choice:  , Probability: 0.1678

# %%
import os
import csv
import clip
from PIL import Image
import torch

def load_clip_model():
    # Load the CLIP model from OpenAI
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model, preprocess = clip.load("ViT-B/32", device=device)
    return model, preprocess, device

def predict_choice(model, preprocess, device, image_path, text_descriptions):
    # Preprocess the image and tokenize the text descriptions
    image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
    text_tokens = clip.tokenize(text_descriptions).to(device)

    with torch.no_grad():
        # Encode image and text with the CLIP model
        image_features = model.encode_image(image)
        text_features = model.encode_text(text_tokens)

        # Calculate the similarity scores and convert to probabilities
        logits_per_image = (image_features @ text_features.T).softmax(dim=-1)
        probs = logits_per_image.cpu().numpy()

    return probs[0]




def main():
    model, preprocess, device = load_clip_model()
    base_dir = "clip_dataset"
    images_dir = os.path.join(base_dir, "images")
    csv_file_path = os.path.join(base_dir, "dataset.csv")

    with open(csv_file_path, 'r', newline='', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            image_path = os.path.join(images_dir, row["image_filename"])
            text_description = row["text_description"]
            choices = row["button_texts"].split('|')

            # 'many' が text_description に含まれているかをチェック
            if "many" in text_description:
                parts = text_description.split(" ")
                try:
                    items_index = parts.index("many") + 1
                    items_phrase = " ".join(parts[items_index:-2]) 
                except ValueError:
                    # 'many' の後に 'are there' が見つからない場合はスキップ
                    print(f"Error in text description for image: {row['image_filename']}")
                    continue

                # 各選択肢に対する説明文を生成
                text_descriptions = [f"There are {choice} {items_phrase}." for choice in choices]
            else:
                # 'many' がなければ、デフォルトのフレーズを使用
                text_descriptions = [f"There are {choice} items." for choice in choices]

            # CLIPモデルによる予測
            probs = predict_choice(model, preprocess, device, image_path, text_descriptions)
            best_choice_index = probs.argmax()
            selected_choice = choices[best_choice_index] if choices[best_choice_index] != ' ' else 'No valid choice'
            print(f"Image: {row['image_filename']}, Best choice: {selected_choice}, Probability: {probs[best_choice_index]:.4f}")

if __name__ == "__main__":
    main()
# Out:
# Image: image_0001.png, Best choice: 1, Probability: 0.2666
# Image: image_0002.png, Best choice: 2, Probability: 0.3506
# Image: image_0003.png, Best choice: 2, Probability: 0.4395
# Image: image_0004.png, Best choice: 2, Probability: 0.2939
# Image: image_0005.png, Best choice: 3, Probability: 0.2769
# Image: image_0006.png, Best choice: 3, Probability: 0.1641
# Image: image_0007.png, Best choice: 3, Probability: 0.5615
# Image: image_0008.png, Best choice: 4, Probability: 0.2568
# Image: image_0009.png, Best choice: 2, Probability: 0.3362
# Image: image_0010.png, Best choice: 2, Probability: 0.3718
# Image: image_0011.png, Best choice: 6, Probability: 0.2817
# Image: image_0012.png, Best choice: 0, Probability: 0.2903
# Image: image_0013.png, Best choice: 8, Probability: 0.2285
# Image: image_0014.png, Best choice: No valid choice, Probability: 0.1887
# Image: image_0015.png, Best choice: No valid choice, Probability: 0.1416
# Image: image_0016.png, Best choice: 2, Probability: 0.3442
# Image: image_0017.png, Best choice: 4, Probability: 0.3079
# Image: image_0018.png, Best choice: 3, Probability: 0.2661
# Image: image_0019.png, Best choice: 0, Probability: 0.2554
# Image: image_0020.png, Best choice: No valid choice, Probability: 0.1552
# Image: image_0021.png, Best choice: 3, Probability: 0.3921
# Image: image_0022.png, Best choice: 3, Probability: 0.1912
# Image: image_0023.png, Best choice: 4, Probability: 0.2292
# Image: image_0024.png, Best choice: 0, Probability: 0.2805
# Image: image_0025.png, Best choice: 2, Probability: 0.2646
# Image: image_0026.png, Best choice: 2, Probability: 0.6152
# Image: image_0027.png, Best choice: No valid choice, Probability: 0.1263
# Image: image_0028.png, Best choice: No valid choice, Probability: 0.2251
# Image: image_0029.png, Best choice: 0, Probability: 0.4836
# Image: image_0030.png, Best choice: 3, Probability: 0.4158
# Image: image_0031.png, Best choice: 2, Probability: 0.4468
# Image: image_0032.png, Best choice: 4, Probability: 0.3171
# Image: image_0033.png, Best choice: 8, Probability: 0.5063
# Image: image_0034.png, Best choice: 2, Probability: 0.5151
# Image: image_0035.png, Best choice: 5, Probability: 0.2754
# Image: image_0036.png, Best choice: 6, Probability: 0.3567
# Image: image_0037.png, Best choice: 2, Probability: 0.3794
# Image: image_0038.png, Best choice: 6, Probability: 0.2219
# Image: image_0039.png, Best choice: 2, Probability: 0.3279
# Image: image_0040.png, Best choice: 3, Probability: 0.5420
# Image: image_0041.png, Best choice: 4, Probability: 0.2578
# Image: image_0042.png, Best choice: 2, Probability: 0.5376
# Image: image_0043.png, Best choice: 3, Probability: 0.5107
# Image: image_0044.png, Best choice: 4, Probability: 0.1749
# Image: image_0045.png, Best choice: 5, Probability: 0.2598
# Image: image_0046.png, Best choice: 1, Probability: 0.1602
# Image: image_0047.png, Best choice: 4, Probability: 0.2026
# Image: image_0048.png, Best choice: 3, Probability: 0.2434
# Image: image_0049.png, Best choice: 3, Probability: 0.4282
# Image: image_0050.png, Best choice: 1, Probability: 0.2949
# Image: image_0051.png, Best choice: 0, Probability: 0.3696
# Image: image_0052.png, Best choice: 2, Probability: 0.4026
# Image: image_0053.png, Best choice: 3, Probability: 0.3303
# Image: image_0054.png, Best choice: 4, Probability: 0.3521
# Image: image_0055.png, Best choice: 0, Probability: 0.1904
# Image: image_0056.png, Best choice: 1, Probability: 0.2008
# Image: image_0057.png, Best choice: 3, Probability: 0.1985
# Image: image_0058.png, Best choice: 4, Probability: 0.3296
# Image: image_0059.png, Best choice: 2, Probability: 0.2299
# Image: image_0060.png, Best choice: No valid choice, Probability: 0.1703
# Image: image_0061.png, Best choice: 2, Probability: 0.4119
# Image: image_0062.png, Best choice: 2, Probability: 0.3848
# Image: image_0063.png, Best choice: 0, Probability: 0.5215
# Image: image_0064.png, Best choice: 4, Probability: 0.3928
# Image: image_0065.png, Best choice: 2, Probability: 0.1661
# Image: image_0066.png, Best choice: 6, Probability: 0.2430
# Image: image_0067.png, Best choice: 0, Probability: 0.2749
# Image: image_0068.png, Best choice: 2, Probability: 0.5664
# Image: image_0069.png, Best choice: 2, Probability: 0.3950
# Image: image_0070.png, Best choice: 2, Probability: 0.4075
# Image: image_0071.png, Best choice: 3, Probability: 0.3308
# Image: image_0072.png, Best choice: 6, Probability: 0.2316
# Image: image_0073.png, Best choice: 8, Probability: 0.3191
# Image: image_0074.png, Best choice: 2, Probability: 0.2483
# Image: image_0075.png, Best choice: 2, Probability: 0.2693
# Image: image_0076.png, Best choice: 2, Probability: 0.4099
# Image: image_0077.png, Best choice: 0, Probability: 0.2720
# Image: image_0078.png, Best choice: 3, Probability: 0.5308
# Image: image_0079.png, Best choice: 2, Probability: 0.4224
# Image: image_0080.png, Best choice: No valid choice, Probability: 0.1515
# Image: image_0081.png, Best choice: 2, Probability: 0.3760
# Image: image_0082.png, Best choice: 3, Probability: 0.4880
# Image: image_0083.png, Best choice: 3, Probability: 0.5186
# Image: image_0084.png, Best choice: 1, Probability: 0.2527
# Image: image_0085.png, Best choice: 4, Probability: 0.1465
# Image: image_0086.png, Best choice: 2, Probability: 0.4207
# Image: image_0087.png, Best choice: 2, Probability: 0.5215
# Image: image_0088.png, Best choice: 2, Probability: 0.3115
# Image: image_0089.png, Best choice: No valid choice, Probability: 0.1549
# Image: image_0090.png, Best choice: 0, Probability: 0.1747
# Image: image_0091.png, Best choice: No valid choice, Probability: 0.2278
# Image: image_0092.png, Best choice: 9, Probability: 0.2798
# Image: image_0093.png, Best choice: No valid choice, Probability: 0.2126
# Image: image_0094.png, Best choice: 2, Probability: 0.2981
# Image: image_0095.png, Best choice: 4, Probability: 0.2871
# Image: image_0096.png, Best choice: 2, Probability: 0.3982
# Image: image_0097.png, Best choice: 0, Probability: 0.2590
# Image: image_0098.png, Best choice: No valid choice, Probability: 0.1748
# Image: image_0099.png, Best choice: 2, Probability: 0.2316
